# %% [markdown]
# # Assignment
#
# The assignment will require you to complete cells, create new ones, and move around some cells. You need to familiarize yourself with the Jupyter notebook interface. You can find a tutorial [here](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).

# %% [markdown]
# ---

# %% [markdown]
# <h1>[EXERCISE 1]</h1>
# <h5>Tomas Joaquin Monteiro</h5>
# <h5>email: tjmonteiro@mail.austra.edu.ar</h5>
#
# ![bariloche-1.jpg](attachment:bariloche-1.jpg)
# https://ibb.co/FmyTcLR
#
# En esta imagen se observa varias de las hermosas montañas que caracterizan a Bariloche, junto con un encantador lago. Las imponentes montañas que vemos  atrás se destacan por su majestuosidad y la cobertura de nieve en su cima, Esta combinación de montaña y lago crea un paisaje impresionante.

# %% [markdown]
# # [EXERCISE 2]

# %%
def rectangle_area(width,height):
    area = width*height
    text = f"The area of a rectangle with width {width} and height {height} is {area}"
    return text

# %%
#CREATE A NEW CELL BELOW THIS ONE AND ADD A MARKDOWN TITLE (HEADING 1) WITH THE TEXT "[EXERCISE 2]"
#
#Create a new cell below the one with a markdown title of "[EXERCISE 2]" to solve the following exercise in python, it needs to be a CODE cell:
#
#Write a function rectangle_area(width, height) that takes the width and height of a rectangle as input and returns its area.
#
#Add the instructions of the exercise as a comment in the code cell above the function definition.
#
#DO NOT KEEP THE CELL WITH THESE INSTRUCTIONS.

# %% [markdown]
# # [EXERCISE 3]

# %%
print(rectangle_area(3,4))
print(rectangle_area(5,10))
print(rectangle_area(8,2))
#1. CREATE A NEW CELL BELOW THIS ONE AND ADD A MARKDOWN TITLE (HEADING 1) WITH THE TEXT "[EXERCISE 3]"
#2. Use your created function to calculate the area of a rectangle with width 3 and height 4. Another of width 5 and height 10, and another of width 8 and height 2. Show your results in the same cell with a description of each result. Similar to this example:
#
#        `The area of a rectangle with width 3 and height 4 is 12.`
#3. Add the instructions of the exercise as a comment in the code cell with the solution.
#4. DO NOT KEEP THE CELL WITH THESE INSTRUCTIONS.
# Out:
# The area of a rectangle with width 3 and height 4 is 12
# The area of a rectangle with width 5 and height 10 is 50
# The area of a rectangle with width 8 and height 2 is 16

# %% [markdown]
# # [EXERCISE 5]

# %%
def f(x):
    return x ** 2

def central_difference(f, x, h):
    derivada = (f(x+h)-f(x-h))/(2*(h))
    text = f"The derivative of f(x) = x^2 at x = {x} using h = {h} is {derivada}."
    return text
# Out:
# The derivative of f(x) = x^2 at x = 2 using h = 0.1 is 4.000000000000001.
# The derivative of f(x) = x^2 at x = 2 using h = 0.01 is 3.999999999999937.
# The derivative of f(x) = x^2 at x = 2 using h = 0.001 is 3.9999999999995595.

# %%
print(central_difference(f,2,0.1))
print(central_difference(f,2,0.01))
print(central_difference(f,2,0.001))
# Out:
# The derivative of f(x) = x^2 at x = 2 using h = 0.1 is 4.000000000000001.
# The derivative of f(x) = x^2 at x = 2 using h = 0.01 is 3.999999999999937.
# The derivative of f(x) = x^2 at x = 2 using h = 0.001 is 3.9999999999995595.
