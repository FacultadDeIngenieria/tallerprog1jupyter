# %% [markdown]
# # Assignment
#
# The assignment will require you to complete cells, create new ones, and move around some cells. You need to familiarize yourself with the Jupyter notebook interface. You can find a tutorial [here](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).

# %% [markdown]
# ---

# %% [markdown]
# # [EXERCISE 1]
#
# Vito Contestabile Monti - vcontestabilemonti@mail.austral.edu.ar
#
# ![image.png](attachment:image.png)
#
# El ornitorrinco es uno de los animales más especiales de nuestro planeta. además de tener cola de castor y pico de pato, es el único mamífero que pone huevos. Realmente increíble!

# %% [markdown]
# # [EXERCISE 2]

# %%
#CREATE A NEW CELL BELOW THIS ONE AND ADD A MARKDOWN TITLE (HEADING 1) WITH THE TEXT "[EXERCISE 2]"
#Create a new cell below the one with a markdown title of "[EXERCISE 2]" to solve the following exercise in python, it needs to be a CODE cell:
#Write a function rectangle_area(width, height) that takes the width and height of a rectangle as input and returns its area.

def rectangle_area(width,height):
    return width*height

# %% [markdown]
# # [EXERCISE 3]

# %%
#1.CREATE A NEW CELL BELOW THIS ONE AND ADD A MARKDOWN TITLE (HEADING 1) WITH THE TEXT "[EXERCISE 3]"
#2.Use your created function to calculate the area of a rectangle with width 3 and height 4. Another of width 5 and height 10, and another of width 8 and height 2. Show your results in the same cell with a description of each result. Similar to this example: `The area of a rectangle with width 3 and height 4 is 12.` 
print(f'The area of a rectangle with width 3 and height 4 is {rectangle_area(3,4)}.')
print(f'The area of a rectangle with width 5 and height 10 is {rectangle_area(5,10)}.')
print(f'The area of a rectangle with width 8 and height 2 is {rectangle_area(8,2)}.')
# Out:
# The area of a rectangle with width 3 and height 4 is 12.
# The area of a rectangle with width 5 and height 10 is 50.
# The area of a rectangle with width 8 and height 2 is 16.

# %% [markdown]
# # [EXERCISE 5]

# %%
def central_difference(f, x, h):
    return (f(x+h)-f(x))/h

# %%
def funct(x):
    return x**2
f=funct
x=2
h1=0.1
h2=0.01
h3=0.001
print(f"The derivative of f(x) = x^2 at x = 2 using h = 0.1 is {central_difference(funct, x, h1)}.")
print(f"The derivative of f(x) = x^2 at x = 2 using h = 0.01 is {central_difference(funct, x, h2)}.")
print(f"The derivative of f(x) = x^2 at x = 2 using h = 0.001 is {central_difference(funct, x, h3)}.")
# Out:
# The derivative of f(x) = x^2 at x = 2 using h = 0.1 is 4.100000000000001.
# The derivative of f(x) = x^2 at x = 2 using h = 0.01 is 4.009999999999891.
# The derivative of f(x) = x^2 at x = 2 using h = 0.001 is 4.000999999999699.
