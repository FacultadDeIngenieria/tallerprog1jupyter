# %%
# ASSIGNMENT

The assignment will require you to complete cells, create new ones, and move around some cells. You need to familiarize yourself with the Jupyter notebook interface. You can find a tutorial [here](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).


**MAKE SURE TO MAKE A COPY OF THIS ASSIGNMENT IN YOUR OWN REPOSITORY.** (delete this line in your new copy :))
# Out:
#   Cell In[2], line 3
#     The assignment will require you to complete cells, create new ones, and move around some cells. You need to familiarize yourself with the Jupyter notebook interface. You can find a tutorial [here](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ---

# %% [markdown]
# <h1>EXERCISE 1</h1>
#
# Jose Ignacio Siaba Serrate
#
# email:isiaba@mail.austral.edu.ar
#
# ![Shinjuku-City-512910636.jpg](attachment:Shinjuku-City-512910636.jpg)
#
#
# shinjuku, japon

# %% [markdown]
# # [EXERCISE 2]

# %%
#1. Create a new cell below this one and add a markdown title (heading 1) with the text "[EXERCISE 2]"
#2. Create a new cell below the one with markdown tittle of "[EXERCISE 2]" to solve the following exercise in python, it needs to be a CODE cell:
def rectangle_area(width, height):
    return width*height

# %% [markdown]
# # [EXERCISE 3]

# %%
#CREATE A NEW CELL BELOW THIS ONE AND ADD A MARKDOWN TITLE (HEADING 1) WITH THE TEXT "[EXERCISE 3]"

#Use your created function to calculate the area of a rectangle with width 3 and heigth 4. Another of width 5 and heigth 10, and
 # `The area of the rectangle with width 3 and heigth 4 is 12.´
    
print(f"The area of the rectangle with width 3 and heigth 4 is {rectangle_area(3,4)}.")
print(f"The area of the rectangle with width 5 and heigth 10 is {rectangle_area(5,10)}.")
print(f"The area of the rectangle with width 8 and heigth 2 is {rectangle_area(8,2)}.")
# Out:
# The area of the rectangle with width 3 and heigth 4 is 12.
# The area of the rectangle with width 5 and heigth 10 is 50.
# The area of the rectangle with width 8 and heigth 2 is 16.

# %% [markdown]
# # [EXERCISE 5]

# %%
def central_difference(f, x, h):
    return (f(x+h)- f(x)) /h

# %%
def squere(x): return x ** 2
f = squere
x= 2

h_1 = 0.1
print(f"the derivative of f(x) - x^2 at x {x} using h = {h_1} is {central_difference(squere, x, h_1)}")

h_2 = 0.01
print(f"the derivative of f(x) - x^2 at x {x} using h = {h_2} is {central_difference(squere, x, h_2)}")

h_3 = 0.001
print(f"the derivative of f(x) - x^2 at x {x} using h = {h_3} is {central_difference(squere, x, h_3)}")
# Out:
# the derivative of f(x) - x^2 at x 2 using h = 0.1 is 4.100000000000001
# the derivative of f(x) - x^2 at x 2 using h = 0.01 is 4.009999999999891
# the derivative of f(x) - x^2 at x 2 using h = 0.001 is 4.000999999999699
